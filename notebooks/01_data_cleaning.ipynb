# %% [markdown]
# # 01 Data Cleaning
# Load raw city data and inspect cleaning outputs from src preprocessing pipeline.

# %%
import pandas as pd
ny = pd.read_csv('../data/processed/newyork_listings_clean.csv')
ch = pd.read_csv('../data/processed/chicago_listings_clean.csv')
ny.head(), ch.head()
