# %% [markdown]
# # 02 Feature Engineering
# Create engineered features for pricing and demand analysis.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/newyork_analysis_ready.csv')
df.columns
