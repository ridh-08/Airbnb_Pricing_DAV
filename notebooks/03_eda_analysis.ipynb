# %% [markdown]
# # 03 EDA Analysis
# Generate comparative visual analysis across New York and Chicago.

# %%
import pandas as pd
ny = pd.read_csv('../data/processed/newyork_analysis_ready.csv')
ch = pd.read_csv('../data/processed/chicago_analysis_ready.csv')
ny.describe(include='all').head()
