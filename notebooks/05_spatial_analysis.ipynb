# %% [markdown]
# # 05 Spatial Analysis
# Merge neighbourhood boundaries with listing-level aggregates for maps.

# %%
import geopandas as gpd
gdf = gpd.read_file('../New York/neighbourhoods.geojson')
gdf.head()
