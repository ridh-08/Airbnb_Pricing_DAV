# %% [markdown]
# # 06 Calendar Analysis (Optional)
# Analyze sampled calendar price and availability trends over time.

# %%
import pandas as pd
cal = pd.read_csv('../data/processed/newyork_calendar_sample_clean.csv')
cal.head()
